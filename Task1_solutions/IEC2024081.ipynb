# %% [markdown]
# Run all the cells and make changes to only the allowed cells. Do not change the code in the restricted region

# %% [markdown]
# # New Section

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# %%
dataset_path = "./opencode-dataset/Pest and Disease/Dataset"

train_dir = os.path.join(dataset_path, 'train')
test_dir = os.path.join(dataset_path, 'test')

# Change this code

# %%
train_data = ImageDataGenerator(rescale=1.0/255)
test_data = ImageDataGenerator(rescale=1.0/255)


train_generator = train_data.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_data.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

print("Classes found in the dataset:", train_generator.class_indices)

# Do not change this code
# Out:
# Found 74317 images belonging to 22 classes.
# Found 24981 images belonging to 23 classes.
# Classes found in the dataset: {'anthracnose_cashew': 0, 'bacterial blight_cassava': 1, 'brown spot_cassava': 2, 'fall armyworm_maize': 3, 'grasshoper_maize': 4, 'green mite_cassava': 5, 'gumosis_cashew': 6, 'healthy_cashew': 7, 'healthy_cassava': 8, 'healthy_maize': 9, 'healthy_tomato': 10, 'leaf beetle_maize': 11, 'leaf blight_maize': 12, 'leaf blight_tomato': 13, 'leaf curl_tomato': 14, 'leaf miner_cashew': 15, 'leaf spot_maize': 16, 'mosaic_cassava': 17, 'red rust_cashew': 18, 'septoria leaf spot_tomato': 19, 'streak virus_maize': 20, 'verticulium wilt_tomato': 21}

# %%
# Write the code to display one image of all the 22 classes.
classes = train_generator.class_indices.keys()

from IPython.display import Image

for name in classes:
    loc = os.path.join(train_dir, name)
    imgloc = os.path.join(train_dir, name, os.listdir(loc)[0])

    display(name)
    display(imgloc)
    display(Image(filename=imgloc))
# Out:
# 'anthracnose_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/anthracnose_cashew/5395cashew_train_anthracnose.JPG'
# 'bacterial blight_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/bacterial blight_cassava/2812cassava_train_bb.JPG'
# 'brown spot_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/brown spot_cassava/3144cassava_train_bspot.JPG'
# 'fall armyworm_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/fall armyworm_maize/119maize_train_farmyw.JPG'
# 'grasshoper_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/grasshoper_maize/2335maize_train_grasshoper.JPG'
# 'green mite_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/green mite_cassava/1150cassava_train_gmite.JPG'
# 'gumosis_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/gumosis_cashew/849cashew_train_gumosis.JPG'
# 'healthy_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/healthy_cashew/283cashew_train_healthy.JPG'
# 'healthy_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/healthy_cassava/2186cassava_train_healthy.JPG'
# 'healthy_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/healthy_maize/740maize_train_healthy.JPG'
# 'healthy_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/healthy_tomato/1569tomato_train_healthy.JPG'
# 'leaf beetle_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf beetle_maize/1438maize_train_leaf beetle.JPG'
# 'leaf blight_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf blight_maize/1798maize_train_leaf blight.JPG'
# 'leaf blight_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf blight_tomato/3584tomato_train_leaf blight.JPG'
# 'leaf curl_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf curl_tomato/1970tomato_train_leaf curl.JPG'
# 'leaf miner_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf miner_cashew/4597cashew_train_leaf miner.JPG'
# 'leaf spot_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf spot_maize/2808maize_train_leaf spot.JPG'
# 'mosaic_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/mosaic_cassava/678cassava_train_mosaic.JPG'
# 'red rust_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/red rust_cashew/2072cashew_train_red rust.JPG'
# 'septoria leaf spot_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/septoria leaf spot_tomato/6852tomato_train_septoria leaf spot.JPG'
# 'streak virus_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/streak virus_maize/892maize_train_streak virus.JPG'
# 'verticulium wilt_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/verticulium wilt_tomato/803tomato_train_verticulium wilt.JPG'

# %% [markdown]
# Run all the cells and the output must be clearly visible for all the cells.
