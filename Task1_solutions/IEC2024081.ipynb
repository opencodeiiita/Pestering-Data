# %% [markdown]
# Run all the cells and make changes to only the allowed cells. Do not change the code in the restricted region

# %% [markdown]
# # New Section

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# %%
dataset_path = "./opencode-dataset/Pest and Disease/Dataset"

train_dir = os.path.join(dataset_path, 'train')
test_dir = os.path.join(dataset_path, 'test')

# Change this code

# %%
train_data = ImageDataGenerator(rescale=1.0/255)
test_data = ImageDataGenerator(rescale=1.0/255)


train_generator = train_data.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_data.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

print("Classes found in the dataset:", train_generator.class_indices)

# Do not change this code
# Out:
# Found 74317 images belonging to 22 classes.
# Found 24981 images belonging to 22 classes.
# Classes found in the dataset: {'anthracnose_cashew': 0, 'bacterial_blight_cassava': 1, 'brown_spot_cassava': 2, 'fall_armyworm_maize': 3, 'grasshoper_maize': 4, 'green_mite_cassava': 5, 'gumosis_cashew': 6, 'healthy_cashew': 7, 'healthy_cassava': 8, 'healthy_maize': 9, 'healthy_tomato': 10, 'leaf_beetle_maize': 11, 'leaf_blight_maize': 12, 'leaf_blight_tomato': 13, 'leaf_curl_tomato': 14, 'leaf_miner_cashew': 15, 'leaf_spot_maize': 16, 'mosaic_cassava': 17, 'red_rust_cashew': 18, 'septoria_leaf_spot_tomato': 19, 'streak_virus_maize': 20, 'verticulium_wilt_tomato': 21}

# %%
# Write the code to display one image of all the 22 classes.
classes = train_generator.class_indices.keys()

from IPython.display import Image

for name in classes:
    loc = os.path.join(train_dir, name)
    imgloc = os.path.join(train_dir, name, os.listdir(loc)[0])

    display(name)
    display(imgloc)
    display(Image(filename=imgloc))
# Out:
# 'anthracnose_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/anthracnose_cashew/919cashew_train_anthracnose.JPG'
# 'bacterial_blight_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/bacterial_blight_cassava/3069cassava_train_bb.JPG'
# 'brown_spot_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/brown_spot_cassava/4258cassava_train_bspot.JPG'
# 'fall_armyworm_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/fall_armyworm_maize/395maize_train_farmyw.JPG'
# 'grasshoper_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/grasshoper_maize/908maize_train_grasshoper.JPG'
# 'green_mite_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/green_mite_cassava/51cassava_train_gmite.JPG'
# 'gumosis_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/gumosis_cashew/636cashew_train_gumosis.JPG'
# 'healthy_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/healthy_cashew/4595cashew_train_healthy.JPG'
# 'healthy_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/healthy_cassava/2447cassava_train_healthy.JPG'
# 'healthy_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/healthy_maize/272maize_train_healthy.JPG'
# 'healthy_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/healthy_tomato/1990tomato_train_healthy.JPG'
# 'leaf_beetle_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf_beetle_maize/1505maize_train_leaf beetle.JPG'
# 'leaf_blight_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf_blight_maize/2109maize_train_leaf blight.JPG'
# 'leaf_blight_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf_blight_tomato/4128tomato_train_leaf blight.JPG'
# 'leaf_curl_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf_curl_tomato/271tomato_train_leaf curl.JPG'
# 'leaf_miner_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf_miner_cashew/5507cashew_train_leaf miner.JPG'
# 'leaf_spot_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/leaf_spot_maize/1265maize_train_leaf spot.JPG'
# 'mosaic_cassava'
# './opencode-dataset/Pest and Disease/Dataset/train/mosaic_cassava/2912cassava_train_mosaic.JPG'
# 'red_rust_cashew'
# './opencode-dataset/Pest and Disease/Dataset/train/red_rust_cashew/187cashew_train_red rust.JPG'
# 'septoria_leaf_spot_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/septoria_leaf_spot_tomato/4308tomato_train_septoria leaf spot.JPG'
# 'streak_virus_maize'
# './opencode-dataset/Pest and Disease/Dataset/train/streak_virus_maize/3852maize_train_streak virus.JPG'
# 'verticulium_wilt_tomato'
# './opencode-dataset/Pest and Disease/Dataset/train/verticulium_wilt_tomato/180tomato_train_verticulium wilt.JPG'

# %% [markdown]
# Run all the cells and the output must be clearly visible for all the cells.
